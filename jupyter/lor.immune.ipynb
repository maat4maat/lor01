# %% [markdown]
# # ToDo

# %% [markdown]
# # Подготовка

# %% [markdown]
# ## Настройка графики

# %%
# windows.options(height=5.4, width=7)
oldpar <- par()
par(mar = c(10, 4, 1, 2), "xpd" = FALSE)
par(cex.axis = 2, cex.axis = 2, cex.lab = 2)
options(repr.plot.height = 9, repr.plot.width = 12)
options(warn = -1)

# %% [markdown]
# ## Библиотеки

# %%
options(java.parameters = "-Xmx4096m")

suppressMessages(require(readxl, quietly = TRUE, warn.conflicts = FALSE))

suppressMessages(require(vcd, quietly = TRUE, warn.conflicts = FALSE))
suppressMessages(require(coin, quietly = TRUE, warn.conflicts = FALSE))
# independence_test
suppressMessages(require(agricolae, quietly = TRUE, warn.conflicts = FALSE))
# HSD.test, (Honestly Significant Difference)
suppressMessages(require(pgirmess, quietly = TRUE, warn.conflicts = FALSE))
# kruskalmc
suppressMessages(require(nortest, quietly = TRUE, warn.conflicts = FALSE))
# for normality test in case of N>5000. ad.test -- Anderson-Darling normality test
suppressMessages(require(RcmdrMisc, quietly = TRUE, warn.conflicts = FALSE))
# numSumm

suppressMessages(require(beeswarm, quietly = TRUE, warn.conflicts = FALSE))
suppressMessages(require(lattice, quietly = TRUE, warn.conflicts = FALSE))
suppressMessages(require(mosaic, quietly = TRUE, warn.conflicts = FALSE))
suppressMessages(require(ggplot2, quietly = TRUE, warn.conflicts = FALSE))
suppressMessages(require(ggpubr, quietly = TRUE, warn.conflicts = FALSE))
# ggqqplot
# suppressMessages(require(ggExtra, quietly = TRUE, warn.conflicts = FALSE));
# suppressMessages(require(gridExtra, quietly = TRUE, warn.conflicts = FALSE));
# suppressMessages(require(ggfortify, quietly = TRUE, warn.conflicts = FALSE));
# suppressMessages(require(ggalluvial, quietly = TRUE);                             # flow diagramm
# suppressMessages(require(hrbrthemes, quietly = TRUE, warn.conflicts = FALSE));    # ggparcoord
# suppressMessages(require(GGally, quietly = TRUE, warn.conflicts = FALSE));        # ggparcoord
# suppressMessages(require(viridis, quietly = TRUE, warn.conflicts = FALSE));       # ggparcoord


# suppressMessages(require(rstatix, quietly = TRUE);                                # identify_outliers

suppressMessages(require(dplyr, quietly = TRUE, warn.conflicts = FALSE))
suppressMessages(require(tidyr, quietly = TRUE, warn.conflicts = FALSE))
suppressMessages(require(tidycmprsk, quietly = TRUE, warn.conflicts = FALSE))
# suppressMessages(require(tidyverse, quietly = TRUE, warn.conflicts = FALSE));

suppressMessages(require(IRdisplay, quietly = TRUE, warn.conflicts = FALSE))
# display
# suppressMessages(require(repr, quietly = TRUE, warn.conflicts = FALSE));

# suppressMessages(require(TeachingDemos, quietly = TRUE, warn.conflicts = FALSE));
# suppressMessages(require(Rmisc, quietly = TRUE, warn.conflicts = FALSE));
# suppressMessages(require(ranger, quietly = TRUE, warn.conflicts = FALSE));
# suppressMessages(require(Epi, quietly = TRUE, warn.conflicts = FALSE));
# suppressMessages(require(car, quietly = TRUE, warn.conflicts = FALSE));
# suppressMessages(require(exactRankTests, quietly = TRUE, warn.conflicts = FALSE));
# suppressMessages(require(abind, quietly = TRUE, warn.conflicts = FALSE));
# suppressMessages(require(mstate, quietly = TRUE, warn.conflicts = FALSE));
# suppressMessages(require(gnm, quietly = TRUE, warn.conflicts = FALSE));
# suppressMessages(require(multcomp, quietly = TRUE, warn.conflicts = FALSE));
# suppressMessages(require(scales, quietly = TRUE, warn.conflicts = FALSE));
# suppressMessages(require(Rcmdr, quietly = TRUE, warn.conflicts = FALSE));
# suppressMessages(require(tigerstats, quietly = TRUE, warn.conflicts = FALSE));
# suppressMessages(require(fpp3e, quietly = TRUE, warn.conflicts = FALSE));
# suppressMessages(require(tsibble, quietly = TRUE, warn.conflicts = FALSE));
# suppressMessages(require(lubridate, quietly = TRUE, warn.conflicts = FALSE));
# suppressMessages(require(cowplot, quietly = TRUE, warn.conflicts = FALSE));
# suppressMessages(require(smplot2, quietly = TRUE, warn.conflicts = FALSE));
# suppressMessages(require(biostat3, quietly = TRUE, warn.conflicts = FALSE));
# suppressMessages(require(data.table, quietly = TRUE, warn.conflicts = FALSE));

# %% [markdown]
# ## Данные

# %% [markdown]
# ### Загрузка

# %%
# sessionInfo()
# options(encoding = "UTF-8")
immune <- read_excel("C:\\Analysis\\OTOLARING\\Nidelko\\immune.xlsx", sheet = "данные")

# %% [markdown]
# ### Преобразование

# %% [markdown]
# #### Отбор данных

# %%
immune <- immune %>%
  dplyr::select(!c("дата", "дата воздействия", "интервал")) %>%
  dplyr::rename(время = проведение)
immune <- as.data.frame(immune)

# %% [markdown]
# #### Контрасты

# %%
immune$группа <- factor(immune$группа, c("ОГ1", "ОГ2", "КГ"))
levels(immune$группа)[1] <- "ОГ"
levels(immune$группа)[2] <- "ОГ"

immune$время <- factor(immune$время)

# %% [markdown]
# ### Подключение

# %%
try(detach(immune), silent = TRUE)
immunel <- immune
attach(immunel)

# %% [markdown]
# # Общий анализ

# %%
groupping_variable <- "группа"

# %% [markdown]
# ## Generate code

# %% [markdown]
# for (i in match('WBC abs', names(immunel)):match("ABS ЕКТ (CD3+CD16+)", names(immunel))) {
#     # print(paste(i, names(immunel)[i]))
#     variable_name = names(immunel)[i]
#
#     display_markdown(paste0("## ", variable_name))
#
#
#     display_markdown(paste0("### ", 'Общее'))
#
#     parname = variable_name
#     values = immunel[[parname]]
#     parameter = immunel[[groupping_variable]]
#
#     # histogram
#     for (group_name in levels(immunel[[groupping_variable]])) {
#         if (group_name == 'КГ') {
#             tmpset = immunel %>%
#                 filter(группа == group_name, время == "до терапии")
#             p = try(ggplot(tmpset, aes(x=tmpset[[parname]])) +
#                         geom_histogram(bins=10, coimmune="#e9ecef", alpha=0.4, position = 'dodge') +
#                         scale_fill_manual(values=c(rgb(1,0.6,0,0.2), rgb(0,0.3,0.3,0.2), rgb(0,0.5,0.5,0.2))) +
#                         theme_classic() +
#                         xlab(paste0(parname, ', группа: ', group_name)) +
#                         ylab('количество') +
#                         theme(axis.title = element_text(size=16)
#                               , axis.text = element_text(size=14)
#                               , legend.text = element_text(size=14)
#                               , legend.title = element_text(size=14)
#                              )
#                     )
#         } else {
#             tmpset = immunel %>%
#                 filter(группа == group_name)
#             p = try(ggplot(tmpset, aes(x=tmpset[[parname]], fill=время)) +
#                         geom_histogram(bins=10, coimmune="#e9ecef", alpha=0.4, position = 'dodge') +
#                         scale_fill_manual(values=c(rgb(1,0.6,0,0.2), rgb(0,0.3,0.3,0.2), rgb(0,0.5,0.5,0.2))) +
#                         theme_classic() +
#                         xlab(paste0(parname, ', группа: ', group_name)) +
#                         ylab('количество') +
#                         theme(axis.title = element_text(size=16)
#                               , axis.text = element_text(size=14)
#                               , legend.text = element_text(size=14)
#                               , legend.title = element_text(size=14)
#                              )
#                     )
#         }
#         try(display(p))
#     }
#
#     # summary
#     for (group_name in levels(immunel[[groupping_variable]])) {
#         display(paste0('======================== ', group_name, ' ========================'))
#         if (group_name == 'КГ') {
#             tmpset = immunel %>%
#                 filter(группа == group_name, время == "до терапии")
#         } else {
#             tmpset = immunel %>%
#                 filter(группа == group_name)
#         }
#
#         display(numSummary(tmpset[[parname]], statistics = c("mean", "sd", "IQR", "quantiles")
#                            , quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
#                           )
#                )
#         display(favstats(tmpset[[parname]] ~ tmpset$"время"))
#         display(paste())
#         display(paste())
#     }
#
#     # quantaile
#     for (group_name in levels(immunel[[groupping_variable]])) {
#         display(paste0('======================== ', group_name, ' ========================'))
#         tmpset = immunel %>%
#             filter(группа == group_name)
#
#         # display(try(qqmath(~ tmpset[[parname]] | tmpset$"время", panel = function(x, ...) {panel.qqmathline(x, ...); panel.qqmath(x, ...)}
#         #                    , ylab = parname, xlab=group_name
#         #                   )
#         #            )
#         #         )
#         p = try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
#                 stat_qq(size = 3) +
#                 stat_qq_line(linewidth = 2) +
#                 facet_grid(~ `время`) +
#                 labs(title = group_name, x = "нормальные квантилии", y = parname) +
#                 theme_classic()
#                 )
#         try(display(p))
#     }
#
#     # beeswarm
#     for (group_name in levels(immunel[[groupping_variable]])) {
#         display(paste0('======================== ', group_name, ' ========================'))
#         if (group_name == 'КГ') {
#             tmpset = immunel %>%
#                 filter(группа == group_name, время == "до терапии")
#             try(beeswarm(tmpset[[parname]] ~ 1, method = "swarm", pch = 16
#                          , xlab = paste0(parname, ', группа: ', group_name), ylab = 'количество', cex=1.5)
#                 )
#             try(boxplot(tmpset[[parname]] ~ 1, add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
#         } else {
#             tmpset = immunel %>%
#                 filter(группа == group_name)
#             try(beeswarm(tmpset[[parname]] ~ tmpset$"время", method = "swarm", pch = 16
#                          , xlab = paste0(parname, ', группа: ', group_name), ylab = 'количество', cex=1.5)
#                 )
#             try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
#             #abline(h= (12), lty=2, col = "grey")
#             # par("xpd" = TRUE)
#             # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
#             # par("xpd" = FALSE)
#         }
#     }
#
#
#     display_markdown(paste0("### ", 'Тест на нормальность'))
#
#     for (group_name in levels(immunel[[groupping_variable]])) {
#         display(paste0('======================== ', group_name, ' ========================'))
#         tmpset = immunel %>%
#             filter(группа == group_name)
#
#         for (i in 1:nlevels(`время`)) {
#             display(paste0("Время — ", levels(`время`)[i]))
#             ss = subset(tmpset, tmpset$"время" == levels(`время`)[i])
#             display(try(print(shapiro.test(ss[[parname]]))))
#
#             display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
#             display(paste0(''))
#         }
#         display(paste0(''))
#     }
#
#
#     display_markdown(paste0("### ", 'Сравнение, нормальное распределение'))
#
#     for (group_name in levels(immunel[[groupping_variable]])) {
#         cat(paste0('\n======================== ', group_name, ' ========================\n'))
#         tmpset = immunel %>%
#             filter(группа == group_name)
#
#         if (nlevels(parameter) < 3) {
#             display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
#         } else {
#             agg1.aov = aov(tmpset[[parname]] ~ tmpset$"время")
#             print(agg1.aov)
#             print(summary(agg1.aov))
#             cat("\nTukey post hoc test\n")
#             print(TukeyHSD(agg1.aov, conf.level=.95))
#             op=par(mar=c(4,9,4,2), lwd=2)
#             plot(TukeyHSD(agg1.aov, conf.level=.95), las=1, col="brown", cex.axis=1, line.lwd=2)
#             par(op)
#         }
#     }
#
#     display_markdown(paste0("### ", 'Сравнение, распределение не нормальное'))
#
#     for (group_name in levels(immunel[[groupping_variable]])) {
#         cat(paste0('\n\n======================== ', group_name, ' ========================\n'))
#         tmpset = immunel %>%
#             filter(группа == group_name)
#
#         if (nlevels(parameter) < 3) {
#             display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
#             print(independence_test(tmpset[[parname]] ~ tmpset$"время", data = tmpset,
#                               alternative = "two.sided",
#                               ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
#                               xtrafo = function(data) trafo(data, ordered_trafo = ff)
#                               )
#                   )
#         } else {
#             print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
#             print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
#         }
#     }
#
#
#     display_markdown(paste0("### ", 'График'))
#
#     try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа, method = "swarm", pch = 16
#                  , xlab = parname, ylab = 'количество', cex=1.2)
#         )
#     try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа, add = TRUE, varwidth = TRUE, outline = FALSE
#                 , col = c(rgb(1,0.6,0,0.2), rgb(0,0.5,0.5,0.2))
#                )
#         )
#     #abline(h= (12), lty=2, col = "grey")
#     # par("xpd" = TRUE)
#     # legend(4, -max(immunel[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
#     # par("xpd" = FALSE)
# }

# %% [markdown]
# for (i in match('WBC abs', names(immunel)):match("ABS ЕКТ (CD3+CD16+)", names(immunel))) {
#     # print(paste(i, names(immunel)[i]))
#     variable_name = names(immunel)[i]
#
#     display_text(paste0("## ", variable_name))
#     display_text(paste0("### ", 'Общее'))
#     display_text(paste0('parname = "', variable_name, '"'))
# }

# %% [markdown]
# ## WBC abs

# %% [markdown]
# ### Общее

# %%
parname <- "WBC abs"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## Lymphs

# %% [markdown]
# ### Общее

# %%
parname <- "Lymphs"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## CD3+ T-cells

# %% [markdown]
# ### Общее

# %%
parname <- "CD3+ T-cells"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## Cytotoxic T-cells

# %% [markdown]
# ### Общее

# %%
parname <- "Cytotoxic T-cells"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## CD8 naive

# %% [markdown]
# ### Общее

# %%
parname <- "CD8 naive"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## CD8 TCM

# %% [markdown]
# ### Общее

# %%
parname <- "CD8 TCM"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## CD8 TEM

# %% [markdown]
# ### Общее

# %%
parname <- "CD8 TEM"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## CD8 TEMRA

# %% [markdown]
# ### Общее

# %%
parname <- "CD8 TEMRA"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## T-hepler cells

# %% [markdown]
# ### Общее

# %%
parname <- "T-hepler cells"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## CD4 TCM

# %% [markdown]
# ### Общее

# %%
parname <- "CD4 TCM"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## Tregs

# %% [markdown]
# ### Общее

# %%
parname <- "Tregs"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## PD-1 Exhausted

# %% [markdown]
# ### Общее

# %%
parname <- "PD-1 Exhausted"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## Tim-3 Exhausted

# %% [markdown]
# ### Общее

# %%
parname <- "Tim-3 Exhausted"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## Activated T-cells

# %% [markdown]
# ### Общее

# %%
parname <- "Activated T-cells"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## ABS CD3+ T-cells

# %% [markdown]
# ### Общее

# %%
parname <- "ABS CD3+ T-cells"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## ABS Cytotoxic T-cells

# %% [markdown]
# ### Общее

# %%
parname <- "ABS Cytotoxic T-cells"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## ABS CD8 naive

# %% [markdown]
# ### Общее

# %%
parname <- "ABS CD8 naive"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## ABS CD8 TCM

# %% [markdown]
# ### Общее

# %%
parname <- "ABS CD8 TCM"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## ABS CD8 TEM

# %% [markdown]
# ### Общее

# %%
parname <- "ABS CD8 TEM"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## ABS CD8 TEMRA

# %% [markdown]
# ### Общее

# %%
parname <- "ABS CD8 TEMRA"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## ABS T-hepler cells

# %% [markdown]
# ### Общее

# %%
parname <- "ABS T-hepler cells"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## ABS CD4 TCM

# %% [markdown]
# ### Общее

# %%
parname <- "ABS CD4 TCM"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## ABS Tregs

# %% [markdown]
# ### Общее

# %%
parname <- "ABS Tregs"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## ABS PD-1 (CD279) Exhausted CD3+

# %% [markdown]
# ### Общее

# %%
parname <- "ABS PD-1 (CD279) Exhausted CD3+"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## ABS Tim-3 Exhausted (CD3+)

# %% [markdown]
# ### Общее

# %%
parname <- "ABS Tim-3 Exhausted (CD3+)"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## ABS Activated T-cells

# %% [markdown]
# ### Общее

# %%
parname <- "ABS Activated T-cells"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## pDC

# %% [markdown]
# ### Общее

# %%
parname <- "pDC"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## mDC

# %% [markdown]
# ### Общее

# %%
parname <- "mDC"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## CD1c mDC

# %% [markdown]
# ### Общее

# %%
parname <- "CD1c mDC"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## CD141 mDC

# %% [markdown]
# ### Общее

# %%
parname <- "CD141 mDC"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## G-MDSC

# %% [markdown]
# ### Общее

# %%
parname <- "G-MDSC"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## ABS pDC

# %% [markdown]
# ### Общее

# %%
parname <- "ABS pDC"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## ABS mDC

# %% [markdown]
# ### Общее

# %%
parname <- "ABS mDC"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## ABS mDC 1c+

# %% [markdown]
# ### Общее

# %%
parname <- "ABS mDC 1c+"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## ABS mDC 141+

# %% [markdown]
# ### Общее

# %%
parname <- "ABS mDC 141+"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## ABS G-MDSC

# %% [markdown]
# ### Общее

# %%
parname <- "ABS G-MDSC"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## Monocytes (CD14+)

# %% [markdown]
# ### Общее

# %%
parname <- "Monocytes (CD14+)"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## Monocytes Classic (CD14+CD16-)

# %% [markdown]
# ### Общее

# %%
parname <- "Monocytes Classic (CD14+CD16-)"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## Monocytes Interm (CD14+CD16+)

# %% [markdown]
# ### Общее

# %%
parname <- "Monocytes Interm (CD14+CD16+)"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## Monocytes Nonclassic (CD16)

# %% [markdown]
# ### Общее

# %%
parname <- "Monocytes Nonclassic (CD16)"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## В-cells (CD19+CD45+)

# %% [markdown]
# ### Общее

# %%
parname <- "В-cells (CD19+CD45+)"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## ЕК (CD3-CD16+)

# %% [markdown]
# ### Общее

# %%
parname <- "ЕК (CD3-CD16+)"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## ЕКТ (CD3+CD16+)

# %% [markdown]
# ### Общее

# %%
parname <- "ЕКТ (CD3+CD16+)"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## ABS Monocytes (CD14+)

# %% [markdown]
# ### Общее

# %%
parname <- "ABS Monocytes (CD14+)"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## ABS Monocytes Classic (CD14+CD16-)

# %% [markdown]
# ### Общее

# %%
parname <- "ABS Monocytes Classic (CD14+CD16-)"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## ABS Monocytes Interm (CD14+CD16+)

# %% [markdown]
# ### Общее

# %%
parname <- "ABS Monocytes Interm (CD14+CD16+)"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## ABS Monocytes Nonclassic (CD16)

# %% [markdown]
# ### Общее

# %%
parname <- "ABS Monocytes Nonclassic (CD16)"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## ABS В-cells (CD19+CD45+)

# %% [markdown]
# ### Общее

# %%
parname <- "ABS В-cells (CD19+CD45+)"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## ABS ЕК (CD3-CD16+)

# %% [markdown]
# ### Общее

# %%
parname <- "ABS ЕК (CD3-CD16+)"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))

# %% [markdown]
# ## ABS ЕКТ (CD3+CD16+)

# %% [markdown]
# ### Общее

# %%
parname <- "ABS ЕКТ (CD3+CD16+)"

# %%
values <- immunel[[parname]]
parameter <- immunel[[groupping_variable]]
variable_name <- parname

# %%
# histogram
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]])) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    p <- try(ggplot(tmpset, aes(x = tmpset[[parname]], fill = время)) +
      geom_histogram(bins = 10, coimmune = "#e9ecef", alpha = 0.4, position = "dodge") +
      scale_fill_manual(values = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.3, 0.3, 0.2), rgb(0, 0.5, 0.5, 0.2))) +
      theme_classic() +
      xlab(paste0(parname, ", группа: ", group_name)) +
      ylab("количество") +
      theme(
        axis.title = element_text(size = 16),
        axis.text = element_text(size = 14),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 14)
      ))
  }
  try(display(p))
}

# %%
# summary
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  display(numSummary(tmpset[[parname]],
    statistics = c("mean", "sd", "IQR", "quantiles"),
    quantiles = c(0, .25, .5, .75, 1), groups = tmpset$"время"
  ))
  display(favstats(tmpset[[parname]] ~ tmpset$"время"))
  display(paste())
  display(paste())
}

# %%
# quantaile
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
  }

  p <- try(ggplot(tmpset, aes(sample = tmpset[[parname]], colour = `время`)) +
    stat_qq(size = 3) +
    stat_qq_line(linewidth = 2) +
    facet_grid(~`время`) +
    labs(title = group_name, x = "нормальные квантилии", y = parname) +
    theme_classic())
  try(display(p))
}

# %%
# beeswarm
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    try(beeswarm(tmpset[[parname]],
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]], add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)
    try(beeswarm(tmpset[[parname]] ~ tmpset$"время",
      method = "swarm", pch = 16,
      xlab = paste0(parname, ", группа: ", group_name), ylab = "количество", cex = 1.5
    ))
    try(boxplot(tmpset[[parname]] ~ tmpset$"время", add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22"))
    # abline(h= (12), lty=2, col = "grey")
    # par("xpd" = TRUE)
    # legend(1.65, -max(tmpset[[parname]]) * 0.15, levels(tmpset$пол), col = 1:nlevels(tmpset$пол), pch = 16, lty = 1, bty = "n", horiz = FALSE, xjust = 0.5, ncol = 3)
    # par("xpd" = FALSE)
  }
}

# %% [markdown]
# ### Тест на нормальность

# %%
for (group_name in levels(immunel[[groupping_variable]])) {
  display(paste0("======================== ", group_name, " ========================"))
  if (group_name == "КГ") {
    tmpset <- immunel %>%
      filter(группа == group_name, время == "до терапии")
    display(try(shapiro.test(tmpset[[parname]])))
  } else {
    tmpset <- immunel %>%
      filter(группа == group_name)

    for (i in 1:nlevels(`время`)) {
      display(paste0("Время — ", levels(`время`)[i]))
      ss <- subset(tmpset, tmpset$"время" == levels(`время`)[i])
      display(try(shapiro.test(ss[[parname]])))
    }
    display(try(bartlett.test(tmpset[[parname]] ~ tmpset$"время")))
    display(paste0())
    display(paste0())
  }
}

# %% [markdown]
# ### Сравнение, нормальное распределение

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(t.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
    } else {
      agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"время")
      print(agg1.aov)
      print(summary(agg1.aov))
      cat("\nTukey post hoc test\n")
      print(TukeyHSD(agg1.aov, conf.level = .95))
      op <- par(mar = c(4, 9, 4, 2), lwd = 2)
      plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
      par(op)
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(t.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
      } else {
        agg1.aov <- aov(tmpset[[parname]] ~ tmpset$"группа")
        print(agg1.aov)
        print(summary(agg1.aov))
        cat("\nTukey post hoc test\n")
        print(TukeyHSD(agg1.aov, conf.level = .95))
        op <- par(mar = c(4, 9, 4, 2), lwd = 2)
        plot(TukeyHSD(agg1.aov, conf.level = .95), las = 1, col = "brown", cex.axis = 1, line.lwd = 2)
        par(op)
      }
    }
  }
}

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
display(paste0("======================== ВРЕМЯ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  if (group_name != "КГ") {
    display(paste0("============== ", group_name, " =============="))
    tmpset <- immunel %>%
      filter(группа == group_name) %>%
      dplyr::select(c("группа", "uid", "время", parname))
    missing_values <- tmpset %>%
      filter(is.na(tmpset[[parname]])) %>%
      select("uid") %>%
      unique() %>%
      arrange(uid) %>%
      pull()
    tmpset <- tmpset %>%
      filter(!uid %in% c(missing_values))

    if (nlevels(parameter) < 3) {
      display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"время", paired = TRUE)))
      print(independence_test(tmpset[[parname]] ~ tmpset$"время",
        data = tmpset,
        alternative = "two.sided",
        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
        xtrafo = function(data) trafo(data, ordered_trafo = ff)
      ))
    } else {
      print(kruskal.test(tmpset[[parname]] ~ tmpset[["время"]]))
      print(kruskalmc(tmpset[[parname]] ~ tmpset[["время"]]))
    }
  }
}

display(paste0("======================== СРАВНЕНИЕ С КОНТРОЛЕМ ========================"))
for (group_name in levels(immunel[[groupping_variable]])) {
  for (time_name in levels(immunel[["время"]])) {
    if (group_name != "КГ") {
      display(paste0("============== ", group_name, " =============="))
      display(paste0("    ========== ", time_name, " =========="))
      tmpset <- immunel %>%
        filter((группа == group_name | группа == "КГ") & время == time_name) %>%
        dplyr::select(c("группа", "uid", "время", parname))

      if (nlevels(parameter) < 3) {
        display(try(wilcox.test(tmpset[[parname]] ~ tmpset$"группа", paired = FALSE)))
        display(independence_test(tmpset[[parname]] ~ tmpset$"группа",
          data = tmpset,
          alternative = "two.sided",
          ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
          xtrafo = function(data) trafo(data, ordered_trafo = ff)
        ))
      } else {
        display(kruskal.test(tmpset[[parname]] ~ tmpset[["группа"]]))
        display(kruskalmc(tmpset[[parname]] ~ tmpset[["группа"]]))
      }
    }
  }
}

# %% [markdown]
# ### График

# %%
try(beeswarm(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  method = "swarm", pch = 16,
  xlab = parname, ylab = "количество", cex = 1.2
))
try(boxplot(immunel[[parname]] ~ immunel$"время" + immunel$группа,
  add = TRUE, varwidth = TRUE, outline = FALSE,
  col = c(rgb(1, 0.6, 0, 0.2), rgb(0, 0.5, 0.5, 0.2))
))
