# %% [markdown]
# # Полип в день операции

# %% [markdown]
# # Подготовка

# %% [markdown]
# ## Настройка графики

# %%
#windows.options(height=5.4, width=7)
oldpar = par()
par(mar = c(8, 4, 1, 2), "xpd" = FALSE)
options(repr.plot.height = 9, repr.plot.width = 12)
options(warn = -1)

# %% [markdown]
# ## Библиотеки

# %%
options(java.parameters = "-Xmx4096m")

require(readxl, quietly = TRUE, warn.conflicts = FALSE);

require(vcd, quietly = TRUE, warn.conflicts = FALSE);
require(coin, quietly = TRUE, warn.conflicts = FALSE);          # independence_test
require(agricolae, quietly = TRUE, warn.conflicts = FALSE);     # HSD.test
require(pgirmess, quietly = TRUE, warn.conflicts = FALSE);      # kruskalmc
require(nortest, quietly = TRUE, warn.conflicts = FALSE);       # for normality test in case of N>5000. ad.test -- Anderson-Darling normality test
require(RcmdrMisc, quietly = TRUE, warn.conflicts = FALSE);     # numSumm

require(beeswarm, quietly = TRUE, warn.conflicts = FALSE);
require(lattice, quietly = TRUE, warn.conflicts = FALSE);
require(mosaic, quietly = TRUE, warn.conflicts = FALSE);
require(ggplot2, quietly = TRUE, warn.conflicts = FALSE);
require(ggpubr, quietly = TRUE, warn.conflicts = FALSE);        # ggqqplot
#require(ggExtra, quietly = TRUE, warn.conflicts = FALSE);
#require(gridExtra, quietly = TRUE, warn.conflicts = FALSE);
#require(ggfortify, quietly = TRUE, warn.conflicts = FALSE);
require(ggalluvial, quietly = TRUE);                            # flow diagramm
require(hrbrthemes, quietly = TRUE, warn.conflicts = FALSE);    # ggparcoord
require(GGally, quietly = TRUE, warn.conflicts = FALSE);        # ggparcoord
require(viridis, quietly = TRUE, warn.conflicts = FALSE);       # ggparcoord


require(rstatix, quietly = TRUE);                               # identify_outliers
require(dplyr, quietly = TRUE, warn.conflicts = FALSE);
require(tidyr, quietly = TRUE, warn.conflicts = FALSE);
require(tidycmprsk, quietly = TRUE, warn.conflicts = FALSE);
#require(tidyverse, quietly = TRUE, warn.conflicts = FALSE);

require(IRdisplay, quietly = TRUE, warn.conflicts = FALSE);
require(repr, quietly = TRUE, warn.conflicts = FALSE);

require(knitr, quietly = TRUE, warn.conflicts = FALSE);        # Dynamic reports
# Out:
# Registered S3 method overwritten by 'mosaic':
#   method                           from
#   fortify.SpatialPolygonsDataFrame ggplot2
# The 'mosaic' package masks several functions from core packages in order to add
# additional features.  The original behavior of these functions should not be affected by this.
# Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2
# Attaching package: 'rstatix'
# The following objects are masked from 'package:mosaic':
#
#     cor_test, prop_test, t_test
# The following objects are masked from 'package:coin':
#
#     chisq_test, friedman_test, kruskal_test, sign_test, wilcox_test
# The following object is masked from 'package:stats':
#
#     filter

# %% [markdown]
# ## Данные

# %% [markdown]
# ### Загрузка

# %%
#sessionInfo()
#options(encoding = "UTF-8")
lor = read_excel("C:\\Analysis\\OTOLARING\\Nidelko\\mucous20240825.xlsx", sheet="данные")
# lor = as.data.frame(lor)

# %% [markdown]
# ### Преобразование

# %% [markdown]
# #### Отбор данных

# %%
lor = lor %>% 
    dplyr::select("id", "группа", "локация", "этап", "поле", "круглоклеточная воспалительная инфильтрация", 
                  "бокаловидные клетки", "отек", "реснички эпителия", "фиброз", "гиперплазия респираторного эпителия", 
                  "плоскоклеточная метаплазия", "эозинофилы", "нейтрофилы"
                  ) %>%
    filter(локация == "полип") %>%
    filter(этап == 'день операции') %>%
    filter(группа != 'КГ1')
lor = as.data.frame(lor)
lor$группа
# Out:
#   [1] "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "КГ" "КГ" "КГ" "КГ" "КГ"
#  [16] "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "КГ" "КГ" "КГ" "КГ" "КГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ"
#  [31] "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "КГ" "КГ" "КГ" "КГ" "КГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ"
#  [46] "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "КГ" "КГ" "КГ" "КГ" "КГ" "КГ" "КГ" "КГ" "КГ" "КГ"
#  [61] "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ"
#  [76] "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ"
#  [91] "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "КГ" "КГ" "КГ" "КГ" "КГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ"
# [106] "КГ" "КГ" "КГ" "КГ" "КГ" "КГ" "КГ" "КГ" "КГ" "КГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ"
# [121] "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "КГ" "КГ" "КГ" "КГ" "КГ"
# [136] "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ" "ОГ"

# %% [markdown]
# #### Контрасты

# %%
lor$группа = factor(lor$группа, c("ОГ", "КГ"))

lor$"локация" = factor(lor$"локация")
lor$"этап" = factor(lor$"этап", c("день операции", "6-7 сутки", "1-3 мес.", "1 год"))

# %% [markdown]
# #### Медианные значения

# %%
lor_mean <- lor %>%
    group_by(id, группа, локация, этап) %>%
    summarise(
        across(c(
                "круглоклеточная воспалительная инфильтрация", 
                  "бокаловидные клетки", "отек", "реснички эпителия", "фиброз", "гиперплазия респираторного эпителия", 
                  "плоскоклеточная метаплазия", "эозинофилы", "нейтрофилы"
                ),
            ~ median(.x, na.rm = TRUE)
        ),
        .groups = "drop"
        # mean_value = mean(measurement_value, na.rm = TRUE),
        # median_value = median(measurement_value, na.rm = TRUE),
        # sd_value = sd(measurement_value, na.rm = TRUE),
        # min_value = min(measurement_value, na.rm = TRUE),
        # max_value = max(measurement_value, na.rm = TRUE)
    ) %>%
    arrange(id) 
# %>%
#     kable(digits = 2)
# lor_mean

# %% [markdown]
# ### Подключение

# %%
lor = lor_mean
try(detach(lor), silent = TRUE)
attach(lor)

# %% [markdown]
# # Общий анализ

# %%
groupping_variable = 'группа'

# %% [markdown]
# ## круглоклеточная воспалительная инфильтрация

# %% [markdown]
# ### Общее

# %%
parname = "круглоклеточная воспалительная инфильтрация"
values = lor[[parname]]
parameter = lor[[groupping_variable]]

# %%
try(histogram(~ values | parameter, ylab = "% от общего количества", col = "light blue", xlab = parname))
# Out:
# plot without title

# %%
numSummary(values, statistics = c("mean", "sd", "IQR", "quantiles"),
           quantiles = c(0, .25, .5, .75, 1), groups = parameter)
favstats(values ~ parameter)
# Out:
#        mean        sd IQR 0% 25% 50% 75% 100% data:n
# ОГ 1.263158 0.7334928   1  0   1   1   2    3     19
# КГ 1.444444 0.8819171   1  0   1   1   2    3      9
#   parameter min Q1 median Q3 max mean     sd        n  missing
# 1 ОГ        0   1  1      2  3   1.263158 0.7334928 19 0
# 2 КГ        0   1  1      2  3   1.444444 0.8819171  9 0

# %%
qqmath(~ values | parameter, panel = function(x, ...) {panel.qqmathline(x, ...); panel.qqmath(x, ...)}, ylab = parname)
# Out:
# plot without title

# %%
beeswarm(values ~ parameter, data = lor, method = "swarm", pch = 16, xlab = parname)
boxplot(values ~ parameter, data = lor, add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22")
#abline(h= (12), lty=2, col = "grey")
# Out:
# plot without title

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
if (nlevels(parameter) < 3) {
    print(wilcox.test(values ~ parameter))
    independence_test(values ~ parameter, data = lor,
                  alternative = "two.sided",
                  ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
                  xtrafo = function(data) trafo(data, ordered_trafo = ff)
                  )
} else {
    try(print(kruskal.test(values ~ parameter)))
    print(kruskalmc(values ~ parameter))

    cat("\n==========\nPairwise comparison \n")
    for (i in 1:(nlevels(parameter) - 1)) {
        for (j in (i + 1):nlevels(parameter)) {
            cat("\nГруппы — ", levels(parameter)[i], ", ", levels(parameter)[j])
            ss = subset(lor, parameter == levels(lor[[groupping_variable]])[i] | parameter == levels(lor[[groupping_variable]])[j])
            try(print(wilcox.test(ss[[parname]] ~ ss[[groupping_variable]], exact = TRUE)))
            print(independence_test(ss[[parname]] ~ ss[[groupping_variable]], data = ss,
                        alternative = "two.sided",
                        distribution = "exact",
                        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
                        xtrafo = function(data) trafo(data, ordered_trafo = ff)
                        )
                  )
        }
    }
}
# Out:
# 	Wilcoxon rank sum test with continuity correction
#
# data:  values by parameter
# W = 75, p-value = 0.5875
# alternative hypothesis: true location shift is not equal to 0
# 	Asymptotic General Independence Test
#
# data:  values by parameter (ОГ, КГ)
# Z = -0.56957, p-value = 0.569
# alternative hypothesis: two.sided

# %% [markdown]
# ## бокаловидные клетки

# %% [markdown]
# ### Общее

# %%
parname = "бокаловидные клетки"
values = lor[[parname]]
parameter = lor[[groupping_variable]]

# %%
try(histogram(~ values | parameter, ylab = "% от общего количества", col = "light blue", xlab = parname))
# Out:
# plot without title

# %%
numSummary(values, statistics = c("mean", "sd", "IQR", "quantiles"),
           quantiles = c(0, .25, .5, .75, 1), groups = parameter)
favstats(values ~ parameter)
# Out:
#        mean       sd IQR 0% 25% 50% 75% 100% data:n
# ОГ 1.026316 1.111477   2  0   0   1   2    3     19
# КГ 1.000000 1.118034   2  0   0   1   2    3      9
#   parameter min Q1 median Q3 max mean     sd       n  missing
# 1 ОГ        0   0  1      2  3   1.026316 1.111477 19 0
# 2 КГ        0   0  1      2  3   1.000000 1.118034  9 0

# %%
qqmath(~ values | parameter, panel = function(x, ...) {panel.qqmathline(x, ...); panel.qqmath(x, ...)}, ylab = parname)
# Out:
# plot without title

# %%
beeswarm(values ~ parameter, data = lor, method = "swarm", pch = 16, xlab = parname)
boxplot(values ~ parameter, data = lor, add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22")
#abline(h= (12), lty=2, col = "grey")
# Out:
# plot without title

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
if (nlevels(parameter) < 3) {
    print(wilcox.test(values ~ parameter))
    independence_test(values ~ parameter, data = lor,
                  alternative = "two.sided",
                  ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
                  xtrafo = function(data) trafo(data, ordered_trafo = ff)
                  )
} else {
    try(print(kruskal.test(values ~ parameter)))
    print(kruskalmc(values ~ parameter))

    cat("\n==========\nPairwise comparison \n")
    for (i in 1:(nlevels(parameter) - 1)) {
        for (j in (i + 1):nlevels(parameter)) {
            cat("\nГруппы — ", levels(parameter)[i], ", ", levels(parameter)[j])
            ss = subset(lor, parameter == levels(lor[[groupping_variable]])[i] | parameter == levels(lor[[groupping_variable]])[j])
            try(print(wilcox.test(ss[[parname]] ~ ss[[groupping_variable]], exact = TRUE)))
            try(print(independence_test(ss[[parname]] ~ ss[[groupping_variable]], data = ss,
                        alternative = "two.sided",
                        distribution = "exact",
                        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
                        xtrafo = function(data) trafo(data, ordered_trafo = ff)
                        )
                  )
            )
        }
    }
}
# Out:
# 	Wilcoxon rank sum test with continuity correction
#
# data:  values by parameter
# W = 86, p-value = 1
# alternative hypothesis: true location shift is not equal to 0
# 	Asymptotic General Independence Test
#
# data:  values by parameter (ОГ, КГ)
# Z = 0.026201, p-value = 0.9791
# alternative hypothesis: two.sided

# %% [markdown]
# ## отек

# %% [markdown]
# ### Общее

# %%
parname = "отек"
values = lor[[parname]]
parameter = lor[[groupping_variable]]

# %%
try(histogram(~ values | parameter, ylab = "% от общего количества", col = "light blue", xlab = parname))
# Out:
# plot without title

# %%
numSummary(values, statistics = c("mean", "sd", "IQR", "quantiles"), 
           quantiles = c(0, .25, .5, .75, 1), groups = parameter)
favstats(values ~ parameter)
# Out:
#        mean        sd IQR 0% 25% 50% 75% 100% data:n
# ОГ 2.552632 0.7974741   1  0   2   3   3    3     19
# КГ 3.000000 0.0000000   0  3   3   3   3    3      9
#   parameter min Q1 median Q3 max mean     sd        n  missing
# 1 ОГ        0   2  3      3  3   2.552632 0.7974741 19 0
# 2 КГ        3   3  3      3  3   3.000000 0.0000000  9 0

# %%
qqmath(~ values | parameter, panel = function(x, ...) {panel.qqmathline(x, ...); panel.qqmath(x, ...)}, ylab = parname)
# Out:
# plot without title

# %%
beeswarm(values ~ parameter, data = lor, method = "swarm", pch = 16, xlab = parname)
boxplot(values ~ parameter, data = lor, add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22")
#abline(h= (12), lty=2, col = "grey")
# Out:
# plot without title

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
if (nlevels(parameter) < 3) {
    print(wilcox.test(values ~ parameter))
    independence_test(values ~ parameter, data = lor,
                  alternative = "two.sided",
                  ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
                  xtrafo = function(data) trafo(data, ordered_trafo = ff)
                  )
} else {
    try(print(kruskal.test(values ~ parameter)))
    print(kruskalmc(values ~ parameter))

    cat("\n==========\nPairwise comparison \n")
    for (i in 1:(nlevels(parameter) - 1)) {
        for (j in (i + 1):nlevels(parameter)) {
            cat("\nГруппы — ", levels(parameter)[i], ", ", levels(parameter)[j])
            ss = subset(lor, parameter == levels(lor[[groupping_variable]])[i] | parameter == levels(lor[[groupping_variable]])[j])
            try(print(wilcox.test(ss[[parname]] ~ ss[[groupping_variable]], exact = TRUE)))
            print(independence_test(ss[[parname]] ~ ss[[groupping_variable]], data = ss,
                        alternative = "two.sided",
                        distribution = "exact",
                        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
                        xtrafo = function(data) trafo(data, ordered_trafo = ff)
                        )
                  )
        }
    }
}
# Out:
# 	Wilcoxon rank sum test with continuity correction
#
# data:  values by parameter
# W = 58.5, p-value = 0.06864
# alternative hypothesis: true location shift is not equal to 0
# 	Asymptotic General Independence Test
#
# data:  values by parameter (ОГ, КГ)
# Z = -1.8551, p-value = 0.06358
# alternative hypothesis: two.sided

# %% [markdown]
# ## реснички эпителия

# %% [markdown]
# ### Общее

# %%
parname = "реснички эпителия"
values = lor[[parname]]
parameter = lor[[groupping_variable]]

# %%
try(histogram(~ values | parameter, ylab = "% от общего количества", col = "light blue", xlab = parname))
# Out:
# plot without title

# %%
numSummary(values, statistics = c("mean", "sd", "IQR", "quantiles"),
           quantiles = c(0, .25, .5, .75, 1), groups = parameter)
favstats(values ~ parameter)
# Out:
#        mean        sd IQR 0% 25% 50% 75% 100% data:n
# ОГ 1.157895 0.7647191 0.5  0   1   1 1.5    3     19
# КГ 1.777778 0.6666667 1.0  1   1   2 2.0    3      9
#   parameter min Q1 median Q3  max mean     sd        n  missing
# 1 ОГ        0   1  1      1.5 3   1.157895 0.7647191 19 0
# 2 КГ        1   1  2      2.0 3   1.777778 0.6666667  9 0

# %%
qqmath(~ values | parameter, panel = function(x, ...) {panel.qqmathline(x, ...); panel.qqmath(x, ...)}, ylab = parname)
# Out:
# plot without title

# %%
beeswarm(values ~ parameter, data = lor, method = "swarm", pch = 16, xlab = parname)
boxplot(values ~ parameter, data = lor, add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22")
#abline(h= (12), lty=2, col = "grey")
# Out:
# plot without title

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
if (nlevels(parameter) < 3) {
    print(wilcox.test(values ~ parameter))
    independence_test(values ~ parameter, data = lor,
                  alternative = "two.sided",
                  ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
                  xtrafo = function(data) trafo(data, ordered_trafo = ff)
                  )
} else {
    try(print(kruskal.test(values ~ parameter)))
    print(kruskalmc(values ~ parameter))

    cat("\n==========\nPairwise comparison \n")
    for (i in 1:(nlevels(parameter) - 1)) {
        for (j in (i + 1):nlevels(parameter)) {
            cat("\nГруппы — ", levels(parameter)[i], ", ", levels(parameter)[j])
            ss = subset(lor, parameter == levels(lor[[groupping_variable]])[i] | parameter == levels(lor[[groupping_variable]])[j])
            try(print(wilcox.test(ss[[parname]] ~ ss[[groupping_variable]], exact = TRUE)))
            print(independence_test(ss[[parname]] ~ ss[[groupping_variable]], data = ss,
                        alternative = "two.sided",
                        distribution = "exact",
                        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
                        xtrafo = function(data) trafo(data, ordered_trafo = ff)
                        )
                  )
        }
    }
}
# Out:
# 	Wilcoxon rank sum test with continuity correction
#
# data:  values by parameter
# W = 47, p-value = 0.04155
# alternative hypothesis: true location shift is not equal to 0
# 	Asymptotic General Independence Test
#
# data:  values by parameter (ОГ, КГ)
# Z = -2.0648, p-value = 0.03894
# alternative hypothesis: two.sided

# %% [markdown]
# ## фиброз

# %% [markdown]
# ### Общее

# %%
parname = "фиброз"
values = lor[[parname]]
parameter = lor[[groupping_variable]]

# %%
try(histogram(~ values | parameter, ylab = "% от общего количества", col = "light blue", xlab = parname))
# Out:
# plot without title

# %%
numSummary(values, statistics = c("mean", "sd", "IQR", "quantiles"),
           quantiles = c(0, .25, .5, .75, 1), groups = parameter)
favstats(values ~ parameter)
# Out:
#         mean        sd IQR 0% 25% 50% 75% 100% data:n
# ОГ 0.7894737 1.0316625   2  0   0   0   2    3     19
# КГ 0.4444444 0.5270463   1  0   0   0   1    1      9
#   parameter min Q1 median Q3 max mean      sd        n  missing
# 1 ОГ        0   0  0      2  3   0.7894737 1.0316625 19 0
# 2 КГ        0   0  0      1  1   0.4444444 0.5270463  9 0

# %%
qqmath(~ values | parameter, panel = function(x, ...) {panel.qqmathline(x, ...); panel.qqmath(x, ...)}, ylab = parname)
# Out:
# plot without title

# %%
beeswarm(values ~ parameter, data = lor, method = "swarm", pch = 16, xlab = parname)
boxplot(values ~ parameter, data = lor, add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22")
#abline(h= (12), lty=2, col = "grey")
# Out:
# plot without title

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
if (nlevels(parameter) < 3) {
    print(wilcox.test(values ~ parameter))
    independence_test(values ~ parameter, data = lor,
                  alternative = "two.sided",
                  ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
                  xtrafo = function(data) trafo(data, ordered_trafo = ff)
                  )
} else {
    try(print(kruskal.test(values ~ parameter)))
    print(kruskalmc(values ~ parameter))

    cat("\n==========\nPairwise comparison \n")
    for (i in 1:(nlevels(parameter) - 1)) {
        for (j in (i + 1):nlevels(parameter)) {
            cat("\nГруппы — ", levels(parameter)[i], ", ", levels(parameter)[j])
            ss = subset(lor, parameter == levels(lor[[groupping_variable]])[i] | parameter == levels(lor[[groupping_variable]])[j])
            try(print(wilcox.test(ss[[parname]] ~ ss[[groupping_variable]], exact = TRUE)))
            print(independence_test(ss[[parname]] ~ ss[[groupping_variable]], data = ss,
                        alternative = "two.sided",
                        distribution = "exact",
                        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
                        xtrafo = function(data) trafo(data, ordered_trafo = ff)
                        )
                  )
        }
    }
}
# Out:
# 	Wilcoxon rank sum test with continuity correction
#
# data:  values by parameter
# W = 95.5, p-value = 0.6011
# alternative hypothesis: true location shift is not equal to 0
# 	Asymptotic General Independence Test
#
# data:  values by parameter (ОГ, КГ)
# Z = 0.55038, p-value = 0.5821
# alternative hypothesis: two.sided

# %% [markdown]
# ## гиперплазия респираторного эпителия

# %% [markdown]
# ### Общее

# %%
parname = "гиперплазия респираторного эпителия"
values = lor[[parname]]
parameter = lor[[groupping_variable]]

# %%
try(histogram(~ values | parameter, ylab = "% от общего количества", col = "light blue", xlab = parname))
# Out:
# plot without title

# %%
numSummary(values, statistics = c("mean", "sd", "IQR", "quantiles"),
           quantiles = c(0, .25, .5, .75, 1), groups = parameter)
favstats(values ~ parameter)
# Out:
#        mean        sd IQR 0% 25% 50% 75% 100% data:n
# ОГ 1.263158 0.4524139 0.5  1   1   1 1.5    2     19
# КГ 1.222222 0.4409586 0.0  1   1   1 1.0    2      9
#   parameter min Q1 median Q3  max mean     sd        n  missing
# 1 ОГ        1   1  1      1.5 2   1.263158 0.4524139 19 0
# 2 КГ        1   1  1      1.0 2   1.222222 0.4409586  9 0

# %%
qqmath(~ values | parameter, panel = function(x, ...) {panel.qqmathline(x, ...); panel.qqmath(x, ...)}, ylab = parname)
# Out:
# plot without title

# %%
beeswarm(values ~ parameter, data = lor, method = "swarm", pch = 16, xlab = parname)
boxplot(values ~ parameter, data = lor, add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22")
#abline(h= (12), lty=2, col = "grey")
# Out:
# plot without title

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
if (nlevels(parameter) < 3) {
    print(wilcox.test(values ~ parameter))
    independence_test(values ~ parameter, data = lor,
                  alternative = "two.sided",
                  ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
                  xtrafo = function(data) trafo(data, ordered_trafo = ff)
                  )
} else {
    try(print(kruskal.test(values ~ parameter)))
    print(kruskalmc(values ~ parameter))

    cat("\n==========\nPairwise comparison \n")
    for (i in 1:(nlevels(parameter) - 1)) {
        for (j in (i + 1):nlevels(parameter)) {
            cat("\nГруппы — ", levels(parameter)[i], ", ", levels(parameter)[j])
            ss = subset(lor, parameter == levels(lor[[groupping_variable]])[i] | parameter == levels(lor[[groupping_variable]])[j])
            try(print(wilcox.test(ss[[parname]] ~ ss[[groupping_variable]], exact = TRUE)))
            print(independence_test(ss[[parname]] ~ ss[[groupping_variable]], data = ss,
                        alternative = "two.sided",
                        distribution = "exact",
                        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
                        xtrafo = function(data) trafo(data, ordered_trafo = ff)
                        )
                  )
        }
    }
}
# Out:
# 	Wilcoxon rank sum test with continuity correction
#
# data:  values by parameter
# W = 89, p-value = 0.8441
# alternative hypothesis: true location shift is not equal to 0
# 	Asymptotic General Independence Test
#
# data:  values by parameter (ОГ, КГ)
# Z = 0.22942, p-value = 0.8185
# alternative hypothesis: two.sided

# %% [markdown]
# ## плоскоклеточная метаплазия

# %% [markdown]
# ### Общее

# %%
parname = "плоскоклеточная метаплазия"
values = lor[[parname]]
parameter = lor[[groupping_variable]]

# %%
try(histogram(~ values | parameter, ylab = "% от общего количества", col = "light blue", xlab = parname))
# Out:
# plot without title

# %%
numSummary(values, statistics = c("mean", "sd", "IQR", "quantiles"),
           quantiles = c(0, .25, .5, .75, 1), groups = parameter)
favstats(values ~ parameter)
# Out:
#         mean        sd IQR 0% 25% 50% 75% 100% data:n
# ОГ 0.2105263 0.5353034   0  0   0   0   0    2     19
# КГ 0.6666667 0.7071068   1  0   0   1   1    2      9
#   parameter min Q1 median Q3 max mean      sd        n  missing
# 1 ОГ        0   0  0      0  2   0.2105263 0.5353034 19 0
# 2 КГ        0   0  1      1  2   0.6666667 0.7071068  9 0

# %%
qqmath(~ values | parameter, panel = function(x, ...) {panel.qqmathline(x, ...); panel.qqmath(x, ...)}, ylab = parname)
# Out:
# plot without title

# %%
beeswarm(values ~ parameter, data = lor, method = "swarm", pch = 16, xlab = parname)
boxplot(values ~ parameter, data = lor, add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22")
#abline(h= (12), lty=2, col = "grey")
# Out:
# plot without title

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
if (nlevels(parameter) < 3) {
    print(wilcox.test(values ~ parameter))
    independence_test(values ~ parameter, data = lor,
                  alternative = "two.sided",
                  ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
                  xtrafo = function(data) trafo(data, ordered_trafo = ff)
                  )
} else {
    try(print(kruskal.test(values ~ parameter)))
    print(kruskalmc(values ~ parameter))

    cat("\n==========\nPairwise comparison \n")
    for (i in 1:(nlevels(parameter) - 1)) {
        for (j in (i + 1):nlevels(parameter)) {
            cat("\nГруппы — ", levels(parameter)[i], ", ", levels(parameter)[j])
            ss = subset(lor, parameter == levels(lor[[groupping_variable]])[i] | parameter == levels(lor[[groupping_variable]])[j])
            try(print(wilcox.test(ss[[parname]] ~ ss[[groupping_variable]], exact = TRUE)))
            print(independence_test(ss[[parname]] ~ ss[[groupping_variable]], data = ss,
                        alternative = "two.sided",
                        distribution = "exact",
                        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
                        xtrafo = function(data) trafo(data, ordered_trafo = ff)
                        )
                  )
        }
    }
}
# Out:
# 	Wilcoxon rank sum test with continuity correction
#
# data:  values by parameter
# W = 52.5, p-value = 0.04334
# alternative hypothesis: true location shift is not equal to 0
# 	Asymptotic General Independence Test
#
# data:  values by parameter (ОГ, КГ)
# Z = -2.0515, p-value = 0.04022
# alternative hypothesis: two.sided

# %% [markdown]
# ## эозинофилы

# %% [markdown]
# ### Общее

# %%
parname = "эозинофилы"
values = lor[[parname]]
parameter = lor[[groupping_variable]]

# %%
try(histogram(~ values | parameter, ylab = "% от общего количества", col = "light blue", xlab = parname))
# Out:
# plot without title

# %%
numSummary(values, statistics = c("mean", "sd", "IQR", "quantiles"),
           quantiles = c(0, .25, .5, .75, 1), groups = parameter)
favstats(values ~ parameter)
# Out:
#        mean       sd  IQR 0%  25% 50% 75% 100% data:n
# ОГ 2.131579 1.352386 2.25  0 0.75   3   3    3     19
# КГ 2.000000 1.118034 2.00  0 1.00   2   3    3      9
#   parameter min Q1   median Q3 max mean     sd       n  missing
# 1 ОГ        0   0.75 3      3  3   2.131579 1.352386 19 0
# 2 КГ        0   1.00 2      3  3   2.000000 1.118034  9 0

# %%
qqmath(~ values | parameter, panel = function(x, ...) {panel.qqmathline(x, ...); panel.qqmath(x, ...)}, ylab = parname)
# Out:
# plot without title

# %%
beeswarm(values ~ parameter, data = lor, method = "swarm", pch = 16, xlab = parname)
boxplot(values ~ parameter, data = lor, add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22")
#abline(h= (12), lty=2, col = "grey")
# Out:
# plot without title

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
if (nlevels(parameter) < 3) {
    print(wilcox.test(values ~ parameter))
    independence_test(values ~ parameter, data = lor,
                  alternative = "two.sided",
                  ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
                  xtrafo = function(data) trafo(data, ordered_trafo = ff)
                  )
} else {
    try(print(kruskal.test(values ~ parameter)))
    print(kruskalmc(values ~ parameter))

    cat("\n==========\nPairwise comparison \n")
    for (i in 1:(nlevels(parameter) - 1)) {
        for (j in (i + 1):nlevels(parameter)) {
            cat("\nГруппы — ", levels(parameter)[i], ", ", levels(parameter)[j])
            ss = subset(lor, parameter == levels(lor[[groupping_variable]])[i] | parameter == levels(lor[[groupping_variable]])[j])
            try(print(wilcox.test(ss[[parname]] ~ ss[[groupping_variable]], exact = TRUE)))
            try(print(independence_test(ss[[parname]] ~ ss[[groupping_variable]], data = ss,
                        alternative = "two.sided",
                        distribution = "exact",
                        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
                        xtrafo = function(data) trafo(data, ordered_trafo = ff)
                        )
                  )
            )
        }
    }
}
# Out:
# 	Wilcoxon rank sum test with continuity correction
#
# data:  values by parameter
# W = 96.5, p-value = 0.5552
# alternative hypothesis: true location shift is not equal to 0
# 	Asymptotic General Independence Test
#
# data:  values by parameter (ОГ, КГ)
# Z = 0.61804, p-value = 0.5366
# alternative hypothesis: two.sided

# %% [markdown]
# ## нейтрофилы

# %% [markdown]
# ### Общее

# %%
parname = "нейтрофилы"
values = lor[[parname]]
parameter = lor[[groupping_variable]]

# %%
try(histogram(~ values | parameter, ylab = "% от общего количества", col = "light blue", xlab = parname))
# Out:
# Error in breaks(x, ...) : `width' too small.

# %%
numSummary(values, statistics = c("mean", "sd", "IQR", "quantiles"),
           quantiles = c(0, .25, .5, .75, 1), groups = parameter)
favstats(values ~ parameter)
# Out:
#         mean        sd IQR 0% 25% 50% 75% 100% data:n
# ОГ 0.2105263 0.5353034   0  0   0   0   0    2     19
# КГ 0.0000000 0.0000000   0  0   0   0   0    0      9
#   parameter min Q1 median Q3 max mean      sd        n  missing
# 1 ОГ        0   0  0      0  2   0.2105263 0.5353034 19 0
# 2 КГ        0   0  0      0  0   0.0000000 0.0000000  9 0

# %%
qqmath(~ values | parameter, panel = function(x, ...) {panel.qqmathline(x, ...); panel.qqmath(x, ...)}, ylab = parname)
# Out:
# plot without title

# %%
beeswarm(values ~ parameter, data = lor, method = "swarm", pch = 16, xlab = parname)
boxplot(values ~ parameter, data = lor, add = TRUE, varwidth = TRUE, outline = FALSE, col = "#0000ff22")
#abline(h= (12), lty=2, col = "grey")
# Out:
# plot without title

# %% [markdown]
# ### Сравнение, распределение не нормальное

# %%
if (nlevels(parameter) < 3) {
    print(wilcox.test(values ~ parameter))
    independence_test(values ~ parameter, data = lor,
                  alternative = "two.sided",
                  ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
                  xtrafo = function(data) trafo(data, ordered_trafo = ff)
                  )
} else {
    try(print(kruskal.test(values ~ parameter)))
    print(kruskalmc(values ~ parameter))

    cat("\n==========\nPairwise comparison \n")
    for (i in 1:(nlevels(parameter) - 1)) {
        for (j in (i + 1):nlevels(parameter)) {
            cat("\nГруппы — ", levels(parameter)[i], ", ", levels(parameter)[j])
            ss = subset(lor, parameter == levels(lor[[groupping_variable]])[i] | parameter == levels(lor[[groupping_variable]])[j])
            try(print(wilcox.test(ss[[parname]] ~ ss[[groupping_variable]], exact = TRUE)))
            try(print(independence_test(ss[[parname]] ~ ss[[groupping_variable]], data = ss,
                        alternative = "two.sided",
                        distribution = "exact",
                        ytrafo = function(data) trafo(data, numeric_trafo = rank_trafo),
                        xtrafo = function(data) trafo(data, ordered_trafo = ff)
                        )
                  )
            )
        }
    }
}
# Out:
# 	Wilcoxon rank sum test with continuity correction
#
# data:  values by parameter
# W = 99, p-value = 0.2336
# alternative hypothesis: true location shift is not equal to 0
# 	Asymptotic General Independence Test
#
# data:  values by parameter (ОГ, КГ)
# Z = 1.2371, p-value = 0.2161
# alternative hypothesis: two.sided
